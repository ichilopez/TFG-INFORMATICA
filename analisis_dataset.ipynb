# %% [markdown]
# ## Análisis del dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import image_manager
import importlib
importlib.reload(image_manager)
# Out:
# <module 'image_manager' from 'c:\\Users\\Itziar\\Documents\\Documentos\\TFG-INFORMATICA\\image_manager.py'>

# %%
path_meta = 'C:/Users/Itziar/Documents/Documentos/TFG-INF-DATOS/archive/csv/meta.csv'
path_dicom = 'C:/Users/Itziar/Documents/Documentos/TFG-INF-DATOS/archive/csv/dicom_info.csv'
path_calcification_test = 'C:/Users/Itziar/Documents/Documentos/TFG-INF-DATOS/archive/csv/calc_case_description_test_set.csv'
path_calcification_train = 'C:/Users/Itziar/Documents/Documentos/TFG-INF-DATOS/archive/csv/calc_case_description_train_set.csv'
path_mass_test = 'C:/Users/Itziar/Documents/Documentos/TFG-INF-DATOS/archive/csv/mass_case_description_test_set.csv'
path_mass_train = 'C:/Users/Itziar/Documents/Documentos/TFG-INF-DATOS/archive/csv/mass_case_description_train_set.csv'

# %%
df_meta = pd.read_csv(path_meta)
df_meta
# Out:
#                                       SeriesInstanceUID  \
# 0     1.3.6.1.4.1.9590.100.1.2.117041576511324414842...
# 1     1.3.6.1.4.1.9590.100.1.2.438738396107617880132...
# 2     1.3.6.1.4.1.9590.100.1.2.767416741131676463382...
# 3     1.3.6.1.4.1.9590.100.1.2.296931352612305599800...
# 4     1.3.6.1.4.1.9590.100.1.2.436657670120353100077...
# ...                                                 ...
# 6770  1.3.6.1.4.1.9590.100.1.2.424889390711092892018...
# 6771  1.3.6.1.4.1.9590.100.1.2.627433012114953458354...
# 6772  1.3.6.1.4.1.9590.100.1.2.250048723412722873040...
# 6773  1.3.6.1.4.1.9590.100.1.2.323173986211744534717...
# 6774  1.3.6.1.4.1.9590.100.1.2.880917484135960246153...
#
#                                        StudyInstanceUID Modality  \
# 0     1.3.6.1.4.1.9590.100.1.2.229361142710768138411...       MG
# 1     1.3.6.1.4.1.9590.100.1.2.195593486612988388325...       MG
# 2     1.3.6.1.4.1.9590.100.1.2.257901172612530623323...       MG
# ...

# %%
df_meta['SeriesDescription'].value_counts()
# Out:
# SeriesDescription
# ROI mask images          3565
# full mammogram images    3103
# cropped images            107
# Name: count, dtype: int64

# %%
dicom_data = pd.read_csv(path_dicom)
dicom_data.head()
# Out:
#                                            file_path  \
# 0  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.12930...
# 1  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.24838...
# 2  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.26721...
# 3  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.38118...
# 4  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.38118...
#
#                                           image_path  AccessionNumber  \
# 0  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.129308...              NaN
# 1  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.248386...              NaN
# 2  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.267213...              NaN
# 3  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.381187...              NaN
# 4  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.381187...              NaN
#
#    BitsAllocated  BitsStored BodyPartExamined  Columns  ContentDate  \
# 0             16          16           BREAST      351     20160426
# 1             16          16           BREAST     3526     20160426
# ...

# %%
len(dicom_data)
# Out:
# 10237

# %%
df_nuevo = dicom_data[dicom_data['SeriesDescription'].isna()]
df_nuevo
# Out:
#                                                file_path  \
# 4      CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.38118...
# 27     CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.28160...
# 73     CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.18973...
# 76     CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.31632...
# 85     CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.39710...
# ...                                                  ...
# 10168  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.35934...
# 10197  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.18495...
# 10199  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.36274...
# 10203  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.34010...
# 10204  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.35693...
#
#                                               image_path  AccessionNumber  \
# 4      CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.381187...              NaN
# 27     CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.281604...              NaN
# ...

# %%
ruta_raiz = 'C:/Users/Itziar/Documents/Documentos/TFG-INF-DATOS/archive/jpeg'
contador1 = 0
contador2 = 0

for nombre_carpeta in df_nuevo['SeriesInstanceUID']:
    ruta_actual = os.path.join(ruta_raiz, nombre_carpeta)
    if os.path.isdir(ruta_actual):  # verificamos que sea carpeta
        elementos = os.listdir(ruta_actual)
        if len(elementos) == 1:
            contador1+= 1
        elif len(elementos) == 2:
            contador2 += 1

print("Número de carpetas con solo 1 elemento:", contador1)
print("Número de carpetas con 2 elemento:", contador2)
print("Número total de elementos:",len(df_nuevo))
# Out:
# Número de carpetas con solo 1 elemento: 246
# Número de carpetas con 2 elemento: 320
# Número total de elementos: 566

# %%
calcification_test_data = pd.read_csv(path_calcification_test)
calcification_train_data = pd.read_csv(path_calcification_train)
calcification_train_data
# Out:
#      patient_id  breast density left or right breast image view  \
# 0       P_00005               3                RIGHT         CC
# 1       P_00005               3                RIGHT        MLO
# 2       P_00007               4                 LEFT         CC
# 3       P_00007               4                 LEFT        MLO
# 4       P_00008               1                 LEFT         CC
# ...         ...             ...                  ...        ...
# 1541    P_02566               2                RIGHT        MLO
# 1542    P_02572               2                 LEFT         CC
# 1543    P_02572               2                 LEFT        MLO
# 1544    P_02584               1                 LEFT         CC
# 1545    P_02584               1                 LEFT        MLO
#
#       abnormality id abnormality type              calc type  \
# 0                  1    calcification              AMORPHOUS
# 1                  1    calcification              AMORPHOUS
# ...

# %%
print(len(calcification_train_data))
print(len(calcification_test_data))
# Out:
# 1546
# 326

# %%
mass_test_data = pd.read_csv(path_mass_test)
mass_train_data = pd.read_csv(path_mass_train)
len(mass_test_data)
len(mass_train_data)
# Out:
# 1318

# %%
mass_train_data['mass shape'].unique()
# Out:
# array(['IRREGULAR-ARCHITECTURAL_DISTORTION', 'ARCHITECTURAL_DISTORTION',
#        'OVAL', 'IRREGULAR', 'LYMPH_NODE', 'LOBULATED-LYMPH_NODE',
#        'LOBULATED', 'FOCAL_ASYMMETRIC_DENSITY', 'ROUND',
#        'LOBULATED-ARCHITECTURAL_DISTORTION', 'ASYMMETRIC_BREAST_TISSUE',
#        'LOBULATED-IRREGULAR', nan, 'OVAL-LYMPH_NODE', 'LOBULATED-OVAL',
#        'ROUND-OVAL', 'IRREGULAR-FOCAL_ASYMMETRIC_DENSITY',
#        'ROUND-IRREGULAR-ARCHITECTURAL_DISTORTION', 'ROUND-LOBULATED'],
#       dtype=object)

# %%
mass_train_data
# Out:
#      patient_id  breast_density left or right breast image view  \
# 0       P_00001               3                 LEFT         CC
# 1       P_00001               3                 LEFT        MLO
# 2       P_00004               3                 LEFT         CC
# 3       P_00004               3                 LEFT        MLO
# 4       P_00004               3                RIGHT        MLO
# ...         ...             ...                  ...        ...
# 1313    P_02033               2                RIGHT        MLO
# 1314    P_02079               2                RIGHT         CC
# 1315    P_02079               2                RIGHT        MLO
# 1316    P_02092               2                 LEFT         CC
# 1317    P_02092               2                 LEFT        MLO
#
#       abnormality id abnormality type                          mass shape  \
# 0                  1             mass  IRREGULAR-ARCHITECTURAL_DISTORTION
# ...
