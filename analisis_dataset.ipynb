# %% [markdown]
# ## Análisis del dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Out:
# C:\Users\Itziar\AppData\Local\Temp\ipykernel_16832\3241010608.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Provide the correct path to the CSV file
path_meta = 'C:/Users/Itziar/Documents/Documentos/TFG-INF-DATOS/archive/csv/meta.csv'

# Read the CSV file into a DataFrame
df_meta = pd.read_csv(path_meta)

# Display the DataFrame
df_meta
# Out:
#                                       SeriesInstanceUID  \
# 0     1.3.6.1.4.1.9590.100.1.2.117041576511324414842...
# 1     1.3.6.1.4.1.9590.100.1.2.438738396107617880132...
# 2     1.3.6.1.4.1.9590.100.1.2.767416741131676463382...
# 3     1.3.6.1.4.1.9590.100.1.2.296931352612305599800...
# 4     1.3.6.1.4.1.9590.100.1.2.436657670120353100077...
# ...                                                 ...
# 6770  1.3.6.1.4.1.9590.100.1.2.424889390711092892018...
# 6771  1.3.6.1.4.1.9590.100.1.2.627433012114953458354...
# 6772  1.3.6.1.4.1.9590.100.1.2.250048723412722873040...
# 6773  1.3.6.1.4.1.9590.100.1.2.323173986211744534717...
# 6774  1.3.6.1.4.1.9590.100.1.2.880917484135960246153...
#
#                                        StudyInstanceUID Modality  \
# 0     1.3.6.1.4.1.9590.100.1.2.229361142710768138411...       MG
# 1     1.3.6.1.4.1.9590.100.1.2.195593486612988388325...       MG
# 2     1.3.6.1.4.1.9590.100.1.2.257901172612530623323...       MG
# ...

# %%
path_dicom = 'C:/Users/Itziar/Documents/Documentos/TFG-INF-DATOS/archive/csv/dicom_info.csv'
dicom_data = pd.read_csv(path_dicom)
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_colwidth', None)
dicom_data.head()
# Out:
#                                            file_path  \
# 0  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.12930...
# 1  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.24838...
# 2  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.26721...
# 3  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.38118...
# 4  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.38118...
#
#                                           image_path  AccessionNumber  \
# 0  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.129308...              NaN
# 1  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.248386...              NaN
# 2  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.267213...              NaN
# 3  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.381187...              NaN
# 4  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.381187...              NaN
#
#    BitsAllocated  BitsStored BodyPartExamined  Columns  ContentDate  \
# 0             16          16           BREAST      351     20160426
# 1             16          16           BREAST     3526     20160426
# ...

# %%
path_calc_case_test = 'C:/Users/Itziar/Documents/Documentos/TFG-INF-DATOS/archive/csv/calc_case_description_test_set.csv'
path_calc_case_train = 'C:/Users/Itziar/Documents/Documentos/TFG-INF-DATOS/archive/csv/calc_case_description_train_set.csv'
calc_case_test_data = pd.read_csv(path_calc_case_test)
calc_case_train_data = pd.read_csv(path_calc_case_train)
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_colwidth', None)
calc_case_test_data.head()
calc_case_train_data.head()
# Out:
#   patient_id  breast density left or right breast image view  abnormality id  \
# 0    P_00005               3                RIGHT         CC               1
# 1    P_00005               3                RIGHT        MLO               1
# 2    P_00007               4                 LEFT         CC               1
# 3    P_00007               4                 LEFT        MLO               1
# 4    P_00008               1                 LEFT         CC               1
#
#   abnormality type    calc type calc distribution  assessment  \
# 0    calcification    AMORPHOUS         CLUSTERED           3
# 1    calcification    AMORPHOUS         CLUSTERED           3
# 2    calcification  PLEOMORPHIC            LINEAR           4
# 3    calcification  PLEOMORPHIC            LINEAR           4
# 4    calcification          NaN          REGIONAL           2
#
#                  pathology  subtlety  \
# 0                MALIGNANT         3
# 1                MALIGNANT         3
# ...

# %%
path_mass_case_test = 'C:/Users/Itziar/Documents/Documentos/TFG-INF-DATOS/archive/csv/mass_case_description_test_set.csv'
path_mass_case_train = 'C:/Users/Itziar/Documents/Documentos/TFG-INF-DATOS/archive/csv/mass_case_description_train_set.csv'
mass_case_test_data = pd.read_csv(path_mass_case_test)
mass_case_train_data = pd.read_csv(path_mass_case_train)
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_colwidth', None)
mass_case_test_data.head()
mass_case_train_data.head()
# Out:
#   patient_id  breast_density left or right breast image view  abnormality id  \
# 0    P_00001               3                 LEFT         CC               1
# 1    P_00001               3                 LEFT        MLO               1
# 2    P_00004               3                 LEFT         CC               1
# 3    P_00004               3                 LEFT        MLO               1
# 4    P_00004               3                RIGHT        MLO               1
#
#   abnormality type                          mass shape   mass margins  \
# 0             mass  IRREGULAR-ARCHITECTURAL_DISTORTION     SPICULATED
# 1             mass  IRREGULAR-ARCHITECTURAL_DISTORTION     SPICULATED
# 2             mass            ARCHITECTURAL_DISTORTION    ILL_DEFINED
# 3             mass            ARCHITECTURAL_DISTORTION    ILL_DEFINED
# 4             mass                                OVAL  CIRCUMSCRIBED
#
#    assessment  pathology  subtlety  \
# 0           4  MALIGNANT         4
# ...

# %%
valor = mass_case_test_data.loc[1, "image file path"]
# Out:
# Mass-Test_P_00016_LEFT_MLO/1.3.6.1.4.1.9590.100.1.2.125010935311829990124529079264106154392/1.3.6.1.4.1.9590.100.1.2.85952214611170506017891429690540035518/000000.dcm

# %%
import cv2

# Ruta de la imagen
ruta = "C:/Users/Itziar/Documents/Documentos/TFG-INF-DATOS/archive/jpeg/1.3.6.1.4.1.9590.100.1.2.85952214611170506017891429690540035518.jpg"

# Leer la imagen
imagen = cv2.imread(ruta)

# Mostrar la imagen en una ventana
cv2.imshow("Imagen", imagen)
cv2.waitKey(0)  # Espera hasta que se presione una tecla
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import cv2
#       3 # Ruta de la imagen
#       4 ruta = "C:/Users/Itziar/Documents/Documentos/TFG-INF-DATOS/archive/jpeg/1.3.6.1.4.1.9590.100.1.2.85952214611170506017891429690540035518.jpg"
#
# ModuleNotFoundError: No module named 'cv2'
